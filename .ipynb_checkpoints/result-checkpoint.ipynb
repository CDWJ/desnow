# %%
import math
import numpy as np

def calculate_psnr(img1, img2):
    # img1 and img2 have range [0, 255]
    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    mse = np.mean((img1 - img2)**2)
    if mse == 0:
        return float('inf')
    return 20 * math.log10(255.0 / math.sqrt(mse))


import numpy as np
from PIL import Image 
from scipy.signal import convolve2d
 
def matlab_style_gauss2D(shape=(3,3),sigma=0.5):
    """
    2D gaussian mask - should give the same result as MATLAB's
    fspecial('gaussian',[shape],[sigma])
    """
    m,n = [(ss-1.)/2. for ss in shape]
    y,x = np.ogrid[-m:m+1,-n:n+1]
    h = np.exp( -(x*x + y*y) / (2.*sigma*sigma) )
    h[ h < np.finfo(h.dtype).eps*h.max() ] = 0
    sumh = h.sum()
    if sumh != 0:
        h /= sumh
    return h
 
def filter2(x, kernel, mode='same'):
    return convolve2d(x, np.rot90(kernel, 2), mode=mode)
 
def compute_ssim(im1, im2, k1=0.01, k2=0.03, win_size=11, L=255):
 
    if not im1.shape == im2.shape:
        raise ValueError("Input Imagees must have the same dimensions")
    if len(im1.shape) > 2:
        raise ValueError("Please input the images with 1 channel")
 
    M, N = im1.shape
    C1 = (k1*L)**2
    C2 = (k2*L)**2
    window = matlab_style_gauss2D(shape=(win_size,win_size), sigma=1.5)
    window = window/np.sum(np.sum(window))
 
    if im1.dtype == np.uint8:
        im1 = np.double(im1)
    if im2.dtype == np.uint8:
        im2 = np.double(im2)
 
    mu1 = filter2(im1, window, 'valid')
    mu2 = filter2(im2, window, 'valid')
    mu1_sq = mu1 * mu1
    mu2_sq = mu2 * mu2
    mu1_mu2 = mu1 * mu2
    sigma1_sq = filter2(im1*im1, window, 'valid') - mu1_sq
    sigma2_sq = filter2(im2*im2, window, 'valid') - mu2_sq
    sigmal2 = filter2(im1*im2, window, 'valid') - mu1_mu2
 
    ssim_map = ((2*mu1_mu2+C1) * (2*sigmal2+C2)) / ((mu1_sq+mu2_sq+C1) * (sigma1_sq+sigma2_sq+C2))
 
    return np.mean(np.mean(ssim_map))


def tensor2im(input_image, imtype=np.uint8, desnow=False):
    """"Converts a Tensor array into a numpy image array.
    Parameters:
        input_image (tensor) --  the input image tensor array
        imtype (type)        --  the desired type of the converted numpy array
    """
    if not isinstance(input_image, np.ndarray):
        if isinstance(input_image, torch.Tensor):  # get the data from a variable
            image_tensor = input_image.data
        else:
            return input_image
        image_numpy = image_tensor[0].cpu().float().numpy()  # convert it into a numpy array
        if image_numpy.shape[0] == 1:  # grayscale to RGB
            image_numpy = np.tile(image_numpy, (3, 1, 1))
        result = (np.transpose(image_numpy, (1, 2, 0)) + 1) / 2.0 * 255.0  # post-processing: tranpose and scaling
        if desnow:
            result = (np.transpose(image_numpy, (1, 2, 0))) * 255.0
    else:  # if it is a numpy array, do nothing
        result = input_image
    return result.astype(imtype)
n = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

# %%
import numpy as np
import ast
import importlib.machinery
import sys
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
import matplotlib.pyplot as plt
from torch.autograd import Variable
from torch.optim.lr_scheduler import LambdaLR
import os
import copy
import pandas as pd
from matplotlib import image
from PIL import Image
from network import Snow_loss, Snow_dataset, Snow_model
from new_network import Snow_loss, Snow_dataset, Snow_model as Snow_model_snow
from network_upsampling import Snow_loss, Snow_dataset, Snow_model as Snow_model_up

sys.path.append('./pytorch-CycleGAN-and-pix2pix')
from models.networks import define_G
# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
model = Snow_model_up(initial_size=4).cpu()
# cp = torch.load('./downsampling_desnowNet/best_checkpoint_-0.3642.pt')
cp = torch.load('./downsampling_desnowNet_xavier_256_lr/snapshot_checkpoint_131220.pt')

# cp = torch.load('./small_v4_nobn/best_checkpoint_-0.4431.pt')
model.load_state_dict(cp['model_state_dict'])
model.eval()

# G = define_G(3, 3, 64, 'resnet_9blocks', norm='instance', aspp=True)

# GU = define_G(3, 3, 64, 'unet_256', norm='instance', aspp=True)

# cp = torch.load('./pytorch-CycleGAN-and-pix2pix/checkpoints/snow_cyclegan_aspp/latest_net_G_A.pth')
# G.load_state_dict(cp)
# G.eval()

# cp = torch.load('./pytorch-CycleGAN-and-pix2pix/checkpoints/snow_cycle_gan_unet/latest_net_G_A.pth')
# GU.load_state_dict(cp)
# GU.eval()
n = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

# %%
# /test/Snow100K-S/
# city_read_12603
# winter_japan_10740
# city_read_19791
# crossing_04544

# %%
# z = Image.open(f"./test/Snow100K-M/mask/crossroad_01258.jpg")
# y = Image.open(f"./test/Snow100K-M/gt/crossroad_01258.jpg")
# x = Image.open(f"./test/Snow100K-M/synthetic/crossroad_01258.jpg")
z = Image.open(f"./all/mask/winter_park_12839.jpg")
y = Image.open(f"./all/gt/winter_park_12839.jpg")
x = Image.open(f"./all/synthetic/winter_park_12839.jpg")
z = transforms.Grayscale()(z)
# i, j, h, w = transforms.RandomCrop.get_params(z, output_size=(64, 64))
# z = transforms.ToTensor()(transforms.functional.crop(z, i, j, h, w))
# y = transforms.ToTensor()(transforms.functional.crop(y, i, j, h, w))
# x = transforms.ToTensor()(transforms.functional.crop(x, i, j, h, w))
osize = [256, 256]
re = transforms.Resize(osize, transforms.InterpolationMode.BICUBIC)
x = re(x)
y = re(y)
z = re(z)
z = transforms.ToTensor()(z)
y = transforms.ToTensor()(y)
x = transforms.ToTensor()(x)
# x = x.cuda()
# y_hat = torch.zeros([3, 256, 256])
# z_hat = torch.zeros([1, 256, 256])
with torch.no_grad():
    y_hat, y_prime, z_hat = model(x.unsqueeze(0), train=False)
#     for i in range(0, 4):
#         for j in [0, 3]:
#             y_hat_sub, _, z_hat_sub = model(x[:, i*64:(i+1)*64, j*64:(j+1)*64].unsqueeze(0), train=False)
#             y_hat[:, i*64:(i+1)*64, j*64:(j+1)*64] = y_hat_sub.squeeze(0)
#             z_hat[:, i*64:(i+1)*64, j*64:(j+1)*64] = z_hat_sub.squeeze(0)
#     for j in range(0, 4):
#         for i in [0, 3]:
#             y_hat_sub, _, z_hat_sub = model(x[:, i*64:(i+1)*64, j*64:(j+1)*64].unsqueeze(0), train=False)
#             y_hat[:, i*64:(i+1)*64, j*64:(j+1)*64] = y_hat_sub.squeeze(0)
#             z_hat[:, i*64:(i+1)*64, j*64:(j+1)*64] = z_hat_sub.squeeze(0)
        
#     for i in range(1, 7):
#         for j in range(1, 7): 
            
#             y_hat_sub, _, z_hat_sub = model(x[:, i*32:i*32 + 64, j*32:j*32+64].unsqueeze(0), train=False)
#             y_hat[:, i*32 + 16:i*32 + 64 - 16, j*32 + 16:j*32 + 64 - 16] = y_hat_sub[:, 16:48, 16:48].squeeze(0)
#             z_hat[:, i*32 + 16:i*32 + 64 - 16, j*32 + 16:j*32 + 64 - 16] = y_hat_sub[:, 16:48, 16:48].squeeze(0)

# %%
re2 = transforms.Resize([256, 256], transforms.InterpolationMode.LANCZOS)

# %%
n(x).shape
# Out:
# torch.Size([3, 256, 256])

# %%
nx = n(x)
with torch.no_grad():
    result_GU = GU(nx.unsqueeze(0))
    result_G = G(nx.unsqueeze(0))
    # result_GU = torch.zeros([3, 512, 512])
    # result_G = torch.zeros([3, 512, 512])
    # for i in range(0, 2):
    #     for j in range(0, 2):
    #         result_GU_sub = GU(nx[:, i*256:(i+1)*256, j*256:(j+1)*256].unsqueeze(0))
    #         result_G_sub = G(nx[:, i*256:(i+1)*256, j*256:(j+1)*256].unsqueeze(0))
    #         result_GU[:, i*256:(i+1)*256, j*256:(j+1)*256] = result_GU_sub.squeeze(0)
    #         result_G[:, i*256:(i+1)*256, j*256:(j+1)*256] = result_G_sub.squeeze(0)

# %%
loss = Snow_loss()

# %%
loss(y_hat, y_prime, z_hat, y, z, 0)
# Out:
# tensor(0.3799)

# %%
torch.nn.functional.mse_loss(y_prime, y)
# Out:
# /home/dc3505/anaconda3/envs/em/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Using a target size (torch.Size([3, 256, 256])) that is different to the input size (torch.Size([1, 3, 256, 256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   """Entry point for launching an IPython kernel.
# tensor(0.0032)

# %%
transforms.ToPILImage()(z_hat.squeeze(0))
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FE10C0B4290>

# %%
512 / 64
# Out:
# 8.0

# %%
transforms.ToPILImage()(z)
# plt.imshow(z[0])
# plt.colorbar()
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FE206E0C610>

# %%
transforms.ToPILImage()(y_prime.squeeze(0))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE10C202B10>

# %%
# result = torch.clamp((y_hat.squeeze(0)), min=0, max=1)
# result = (np.transpose(result.numpy(), (1, 2, 0)) * 255.0).astype(np.uint8)
transforms.ToPILImage()(y_hat.squeeze(0))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE10BFAD910>

# %%
transforms.ToPILImage()(x)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE0CE39D190>

# %%
transforms.ToPILImage()(tensor2im(result_GU))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE10BF22B90>

# %%
transforms.ToPILImage()(tensor2im(result_G))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE10C0CA2D0>

# %%
print(compute_ssim(y_hat.cpu().numpy().squeeze(0).reshape(480, -1), y.cpu().numpy().reshape(480, -1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1474840/1694866438.py in <module>
# ----> 1 print(compute_ssim(y_hat.cpu().numpy().squeeze(0).reshape(480, -1), y.cpu().numpy().reshape(480, -1)))
#
# ValueError: cannot reshape array of size 196608 into shape (480,newaxis)

# %%
print(calculate_ssim(y_hat.cpu().numpy().squeeze(0), y.cpu().numpy()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1474840/2996162116.py in <module>
# ----> 1 print(calculate_ssim(y_hat.cpu().numpy().squeeze(0), y.cpu().numpy()))
#
# NameError: name 'calculate_ssim' is not defined

# %%
print(calculate_psnr(255*y.numpy(), tensor2im(result_GU).transpose(2, 0, 1)))
# Out:
# 25.391251112315913

# %%
print(calculate_psnr(255*y.numpy(), tensor2im(result_G).transpose(2, 0, 1)))
# Out:
# 23.35547805654202

# %%
print(calculate_psnr(255*y.numpy(), 255 * y_hat.numpy()))
# Out:
# 19.006348830402764

# %%
print(calculate_psnr(255*y.numpy(), 255 * x.numpy()))
# Out:
# 24.377718285068237

# %%
31.340223019061057 + 21.112120819304117

# %%
28.026450190679505 + 19.69305991288545

# %%
16.83521241169626 + 8.313341480521501
